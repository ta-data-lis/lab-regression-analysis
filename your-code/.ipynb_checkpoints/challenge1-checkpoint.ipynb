# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy import stats

# %%
# Your code here.
student_data = pd.DataFrame({'X': [17,51,27,21,36,48,19,26,54,30], 'Y': [10,1,5,9,4,2,9,6,0,3]})
student_data.head()
# Out:
#     X   Y
# 0  17  10
# 1  51   1
# 2  27   5
# 3  21   9
# 4  36   4

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
# Your code here.
X = student_data['X']
Y = student_data['Y']
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# Your response here. 
'''
for younger and older ages, there seems to be a relationship between age and
number of tardies. younger people arrive late more times and older people
arrive late less times
'''
# Out:
# '\nfor younger and older ages, there seems to be a relationship between age and\nnumber of tardies. younger people arrive late more times and older people\narrive late less times\n'

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.
#correlation:
student_data.corr()
# Out:
#           X         Y
# X  1.000000 -0.939163
# Y -0.939163  1.000000

# %%
#covariance:
student_data.cov()
# Out:
#             X          Y
# X  187.655556 -45.566667
# Y  -45.566667  12.544444

# %%
'''
covariance indicates the direction of the linear relationship between variable
correlation is a function of the covariance and measures both the strength and
direction of linear relationship

covariance assumes the units from the variables while correlation is
dimensionless (because it results from the division of covariance by the product
of standard deviations)

as the correlation value is almost 1, we can say that there is a strong
relationship between age and number of tardies

as the value is negative, this means that while one variable rises, the other
one falls
'''
# Out:
# '\ncovariance indicates the direction of the linear relationship between variable\ncorrelation is a function of the covariance and measures both the strength and\ndirection of linear relationship\n\ncovariance assumes the units from the variables while correlation is\ndimensionless (because it results from the division of covariance by the product\nof standard deviations)\n\nas the correlation value is almost 1, we can say that there is a strong\nrelationship between age and number of tardies\n\nas the value is negative, this means that while one variable rises, the other\none falls\n'

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here.
slope, intercept, r_value, _,std_err = stats.linregress(X,Y)
stats.linregress(X,Y)

# outcome variables = number of tardies
# type of regression = linear regression
# Out:
# LinregressResult(slope=-0.2428207709159808, intercept=12.888803363135768, rvalue=-0.9391626886887121, pvalue=5.56665383455343e-05, stderr=0.03139728816158607)

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
# Your code here.
plt.scatter(X,Y)
plt.plot(X, slope * X + intercept, color ='red')
plt.show()

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
# Your response here. 
'''
as written before, for younger and older ages the regression line gives a good
approach, specially for ages above 45. for this cases, I'd say age is a good
predictor.
within 25-35 range, values are further away from the regression line.
'''
# Out:
# "\nas written before, for younger and older ages the regression line gives a good\napproach, specially for ages above 45. for this cases, I'd say age is a good\npredictor.\nwithin 25-35 range, values are further away from the regression line.\n"

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data

vehicles_data = pd.read_csv(r"C:\Users\Ana André\Ironhack\lab-pandas-deep-dive\your-code\vehicles.csv")

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
vehicles_data.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
# Your response here. 
vehicles_sample = vehicles_data[['Year','Cylinders','Fuel Barrels/Year','Combined MPG','Fuel Cost/Year','CO2 Emission Grams/Mile']]
#vehicles_sample.head()

vehicles_sample.corr()
# Out:
#                              Year  Cylinders  Fuel Barrels/Year  Combined MPG  \
# Year                     1.000000   0.082469          -0.221084      0.204751
# Cylinders                0.082469   1.000000           0.739517     -0.698648
# Fuel Barrels/Year       -0.221084   0.739517           1.000000     -0.909743
# Combined MPG             0.204751  -0.698648          -0.909743      1.000000
# Fuel Cost/Year          -0.091913   0.778153           0.916208     -0.875185
# CO2 Emission Grams/Mile -0.222300   0.752393           0.986189     -0.926229
#
#                          Fuel Cost/Year  CO2 Emission Grams/Mile
# Year                          -0.091913                -0.222300
# Cylinders                      0.778153                 0.752393
# Fuel Barrels/Year              0.916208                 0.986189
# Combined MPG                  -0.875185                -0.926229
# Fuel Cost/Year                 1.000000                 0.930865
# ...

# %%
'''
regarding the correlation matrix, the most importants in determining CO2
emissons are those related with fuel consumption, like fuel barrels/year,
combined MPG or fuel cost/year. anyway, fuel barrels/year has a higher
correlation values so I'd say this one is the most important.
Year is the one that provides the least helpful information.
'''
# Out:
# "\nregarding the correlation matrix, the most importants in determining CO2\nemissons are those related with fuel consumption, like fuel barrels/year,\ncombined MPG or fuel cost/year. anyway, fuel barrels/year has a higher\ncorrelation values so I'd say this one is the most important.\nYear is the one that provides the least helpful information.\n"

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here. 
sns.pairplot(data=vehicles_sample, kind='reg', plot_kws={'line_kws':{'color':'red'} ,'scatter_kws':{'alpha':0.2}})

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
# Your response here. 
# What type of regression are you using? Add your responses as comments after your code.
# Print your regression summary, and interpret the results. What are the most important
# varibles in your model and why? What can conclusions can you draw from your model and 
# how confident in these conclusions are you? Add your responses as comments after your code.
'''
Analysing the results, I think that all variables, except for combined MPG, can be related with the CO2 emission by a linear regression.
In the case of combined MPG, I'd say a non linear regression would fit better.
'''

# %% [markdown]
# ## Challenge 2: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
# Your code here.
parties_data = pd.DataFrame({'X': [1,3,4,6,8,9,11,14], 'Y': [1,2,4,4,5,7,8,13]})
parties_data.head()
# Out:
#    X  Y
# 0  1  1
# 1  3  2
# 2  4  4
# 3  6  4
# 4  8  5

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
# Your code here.

X_parties = parties_data['X']
Y_parties = parties_data['Y']

slope_parties, intercept_parties, r_value_parties, __parties,std_err_parties = stats.linregress(X_parties,Y_parties)

plt.scatter(X_parties,Y_parties)
plt.plot(X_parties, slope_parties * X_parties + intercept_parties, color ='red')
plt.show()

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
parties_data.corr()
# Out:
#          X        Y
# X  1.00000  0.96523
# Y  0.96523  1.00000

# %%
# Your response here. 
'''
analyzing the plot, the regression line seems to really fit the points meaning they are likely very correlated.
'''
# Out:
# '\nanalyzing the plot, the regression line seems to really fit the points meaning they are likely very correlated.\n'

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here.

# removing the point of the party with more people invited
parties_1 = parties_data[parties_data['X'] < 14]

X_1 = parties_1['X']
Y_1 = parties_1['Y']

slope_1, intercept_1, r_value_1, __1,std_err_1 = stats.linregress(X_1,Y_1)

plt.scatter(X_1,Y_1)
plt.plot(X_1, slope_1 * X_1 + intercept_1, color ='red')
plt.show()

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
parties_1.corr()
# Out:
#           X         Y
# X  1.000000  0.971278
# Y  0.971278  1.000000

# %%
# Your response here. 
'''
they now seem more correlated.
the regression line now seems more "embebed" between the points.
'''
