# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Your code here.
student_data = pd.DataFrame({'Age': [17,51,27,21,36,48,19,26,54,30], 'Tardies': [10,1,5,9,4,2,9,6,0,3]})

# %%
student_data
# Out:
#    Age  Tardies
# 0   17       10
# 1   51        1
# 2   27        5
# 3   21        9
# 4   36        4
# 5   48        2
# 6   19        9
# 7   26        6
# 8   54        0
# 9   30        3

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
# Your code here.
plt.scatter(student_data.Age, student_data.Tardies)

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# Your response here. 
# The trend is: the older the student, the less likely he or she is to be late

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.
#correlation:
student_data.corr()
# Out:
#               Age   Tardies
# Age      1.000000 -0.939163
# Tardies -0.939163  1.000000

# %%
# the correlation is represented by a value of -1 to 1, whereby values close to one correspond to a strong
# correlation, values close to 0 correspond to the inexistance of any correlation while values close to zero
# correspond to a strong negative correlation

# %%
#covariance:
student_data.cov()
# Out:
#                 Age    Tardies
# Age      187.655556 -45.566667
# Tardies  -45.566667  12.544444

# %%
# the covariance gives the combined variance of the two variables

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here.
slope, intercept, r_value, _, std_err = stats.linregress(student_data.Age, student_data.Tardies)
plt.scatter(student_data.Age, student_data.Tardies)
plt.plot(student_data.Age, slope*student_data.Age+intercept, color = 'red')
plt.show()

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
# Your response here. 
# The interpolation seems to indicate that there is a correlation
print(r_value)
print(std_err)
# Out:
# -0.9391626886887123
# 0.03139728816158601

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data
cars = pd.read_csv("vehicles.csv")
cars.head(3)
# Out:
#          Make                Model  Year  Engine Displacement  Cylinders  \
# 0  AM General    DJ Po Vehicle 2WD  1984                  2.5        4.0
# 1  AM General     FJ8c Post Office  1984                  4.2        6.0
# 2  AM General  Post Office DJ5 2WD  1985                  2.5        4.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0          19.388824        18           17            17
# 1          25.354615        13           13            13
# 2          20.600625        16           17            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# ...

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
# Your response here. 
ds = cars[["Year", "Cylinders", "Fuel Barrels/Year", "Combined MPG", "Fuel Cost/Year", "CO2 Emission Grams/Mile"]]
ds.head(3)
# Out:
#    Year  Cylinders  Fuel Barrels/Year  Combined MPG  Fuel Cost/Year  \
# 0  1984        4.0          19.388824            17            1950
# 1  1984        6.0          25.354615            13            2550
# 2  1985        4.0          20.600625            16            2100
#
#    CO2 Emission Grams/Mile
# 0               522.764706
# 1               683.615385
# 2               555.437500

# %%
ds.corr()
# Out:
#                              Year  Cylinders  Fuel Barrels/Year  Combined MPG  \
# Year                     1.000000   0.082469          -0.221084      0.204751
# Cylinders                0.082469   1.000000           0.739517     -0.698648
# Fuel Barrels/Year       -0.221084   0.739517           1.000000     -0.909743
# Combined MPG             0.204751  -0.698648          -0.909743      1.000000
# Fuel Cost/Year          -0.091913   0.778153           0.916208     -0.875185
# CO2 Emission Grams/Mile -0.222300   0.752393           0.986189     -0.926229
#
#                          Fuel Cost/Year  CO2 Emission Grams/Mile
# Year                          -0.091913                -0.222300
# Cylinders                      0.778153                 0.752393
# Fuel Barrels/Year              0.916208                 0.986189
# Combined MPG                  -0.875185                -0.926229
# Fuel Cost/Year                 1.000000                 0.930865
# ...

# %%
"""
In the correlation table above we can check for correlations. CO2 emissions strongly correlate with several of the 
variables. The strongest correlation is with Fuel Barrels/year. The correlation closest to 0 is with the year.
"""

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here. 
slope, intercept, r_value, _, std_err = stats.linregress(ds["Fuel Barrels/Year"], ds["CO2 Emission Grams/Mile"])

# %%
plt.scatter(ds["Fuel Barrels/Year"], ds["CO2 Emission Grams/Mile"])
plt.plot(ds["Fuel Barrels/Year"], ds["Fuel Barrels/Year"]*slope+intercept, color='red')
plt.show()

# %%
Y = ds["CO2 Emission Grams/Mile"]
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20, 10)) 

slope1, intercept1, r_value, _, std_err = stats.linregress(ds["Fuel Barrels/Year"], Y)
slope2, intercept2, r_value, _, std_err = stats.linregress((1/ds["Combined MPG"]), Y)
slope3, intercept3, r_value, _, std_err = stats.linregress(ds["Fuel Cost/Year"], Y)
slope4, intercept4, r_value, _, std_err = stats.linregress(ds["Cylinders"], Y)


axs[0][0].scatter(ds["Fuel Barrels/Year"],Y, alpha=0.3)
axs[0][0].plot(ds["Fuel Barrels/Year"],slope1*ds["Fuel Barrels/Year"]+intercept1, color="red")
axs[0][0].set_xlabel('Fuel Barrels/Year')
axs[0][0].set_ylabel('CO2 Emission Grams/Mile')
axs[0][0].legend()

axs[0][1].scatter((1/ds["Combined MPG"]),Y, alpha=0.3)
axs[0][1].plot((1/ds["Combined MPG"]),slope2*(1/ds["Combined MPG"])+intercept2, color="red")
axs[0][1].set_xlabel("1/(Combined MPG)")
axs[0][1].set_ylabel('CO2 Emission Grams/Mile')
axs[0][1].legend()

axs[1][0].scatter(ds["Fuel Cost/Year"],Y, alpha=0.3)
axs[1][0].plot(ds["Fuel Cost/Year"],slope3*ds["Fuel Cost/Year"]+intercept3, color="red")
axs[1][0].set_xlabel("Fuel Cost/Year")
axs[1][0].set_ylabel('CO2 Emission Grams/Mile')
axs[1][0].legend()

axs[1][1].scatter(ds["Cylinders"],Y, alpha=0.3)
axs[1][1].plot(ds["Cylinders"],slope4*ds["Cylinders"]+intercept4, color="red")
axs[1][1].set_xlabel("Cylinders")
axs[1][1].set_ylabel('CO2 Emission Grams/Mile')
axs[1][1].legend()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
sns.pairplot(ds, kind='reg', plot_kws={'line_kws':{'color':'red'}, 'line_kws':{'alpha':0.5}})

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
# Your response here.

# %% [markdown]
# ## Challenge 2: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
# Your code here.
partly = pd.DataFrame({"Invited":[1,3,4,6,8,9,11,14], "Attended":[1,2,4,4,5,7,8,13]})
partly.head()
# Out:
#    Invited  Attended
# 0        1         1
# 1        3         2
# 2        4         4
# 3        6         4
# 4        8         5

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
# Your code here.
slope, intercept, r_value, _, std_err = stats.linregress(partly.Invited, partly.Attended)
slope2, intercept2, r_value, _, std_err = stats.linregress(partly.Invited, (partly.Invited-partly.Attended))


plt.scatter(partly.Invited, partly.Attended)
plt.plot(partly.Invited, partly.Invited*slope+intercept)
plt.xlabel('Invited')
plt.ylabel('Attendants')
plt.show()

plt.scatter(partly.Invited, (partly.Invited-partly.Attended))
plt.plot(partly.Invited, partly.Invited*slope2+intercept2)
plt.xlabel('Invited')
plt.ylabel('Non-Attendants')
plt.show()

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
# Your response here. 
# We see a linear relation between number of invited people and attendents but we also see a trend for number of 
# invited people to non-attendants, though the latter one has a considerable error range

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here. 
partly1 = pd.DataFrame({"Invited":[1,3,6,8,9,11], "Attended":[1,2,4,5,7,8]})

slope3, intercept3, r_value, _, std_err = stats.linregress(partly1.Invited, partly1.Attended)
slope4, intercept4, r_value, _, std_err = stats.linregress(partly1.Invited, (partly1.Invited-partly1.Attended))


plt.scatter(partly1.Invited, partly1.Attended)
plt.plot(partly1.Invited, partly1.Invited*slope3+intercept3)
plt.xlabel('Invited')
plt.ylabel('Attendants')
plt.show()

plt.scatter(partly1.Invited, (partly1.Invited-partly1.Attended))
plt.plot(partly1.Invited, partly1.Invited*slope4+intercept4)
plt.xlabel('Invited')
plt.ylabel('Non-Attendants')
plt.show()

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
# Your response here. 
# Now we see a clear correlation between number of invited and non-attending persons
