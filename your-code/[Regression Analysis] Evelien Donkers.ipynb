# %% [markdown]
# # Lab: Regression Analysis

# %% [markdown]
# ### Before you start:
#
# * Read the README.md file
# * Comment as much as you can and use the resources (README.md file)
#
# Happy learning!

# %%
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Challenge 1
# I work at a coding bootcamp, and I have developed a theory that the younger my students are, the more often they are late to class. In order to test my hypothesis, I have collected some data in the following table:
#
# | StudentID | Age | Tardies |
# |--------|-----|------------|
# | 1      | 17  | 10         |
# | 2      | 51  | 1          |
# | 3      | 27  | 5          |
# | 4      | 21  | 9         |
# | 5      | 36  |  4         |
# | 6      | 48  |  2         |
# | 7      | 19  |  9         |
# | 8      | 26  | 6          |
# | 9      | 54  |  0         |
# | 10     | 30  |  3         |

# %% [markdown]
# Use this command to create a dataframe with the data provided in the table.
# ~~~~
# student_data = pd.DataFrame({'X': [x_values], 'Y': [y_values]})
# ~~~~

# %%
# Your code here.
student_data = pd.DataFrame({'Age': [17, 51, 27, 21, 36, 48, 19, 26, 54, 30], 'Tardies': [10, 1, 5, 9, 4, 2, 9, 6, 0,3]})
student_data

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data.

# %%
# Your code here.

plt.scatter(x="Age", y="Tardies", data=student_data)

# %% [markdown]
# Do you see a trend? Can you make any hypotheses about the relationship between age and number of tardies?

# %%
# Your response here. 
''''Yesssssss, the trend is that the older students get the less they are late '''
'''H: When students are over 50 they will be maximally late one time'''

# %% [markdown]
# Calculate the covariance and correlation of the variables in your plot. What is the difference between these two measures? Compare their values. What do they tell you in this case? Add your responses as comments after your code.

# %%
# Your response here.
#correlation:
cor = student_data[["Age", "Tardies"]].corr()

cor

X = student_data["Age"]
Y = student_data["Tardies"]

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)  
r_value
# Out:
# -0.9391626886887121

# %%
''''The correlantion value(or R_value) shows that there is a big negative correlation between age and Tardiness it's over >0.9'''
# Out:
# -0.9391626886887121

# %%
#covariance:
covari = np.cov(X,Y)
np.corrcoef(X,Y)
covari
# Out:
# array([[187.65555556, -45.56666667],
#        [-45.56666667,  12.54444444]])

# %%
'''The covariance is the actual distance between the points in the matrix, the coeffienct of teh covariance is the same as the
r-value. The covariance doesn't say anything if you don't know the numbers. '''
# Out:
# array([[ 1.        , -0.93916269],
#        [-0.93916269,  1.        ]])

# %% [markdown]
# Build a regression model for this data. What will be your outcome variable? What type of regression are you using? Add your responses as comments after your code.

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)
print ('The slope is: ' + str(slope))
print ('The intercept is: ' + str(intercept))


''''For this model I would use a linear regression as there is a linear association between being late and the age. 
the formula woulde be:

y=ax+b 
y=(-.24*x)+12.89

Y in this case would be the age of the student based on times that the student is late. 
X = student_data["Age"]

'''
# Out:
# The slope is: -0.2428207709159808
# The intercept is: 12.888803363135768
# "'For this model I would use a linear regression as there is a linear association between being late and the age. "

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

Y = student_data["Tardies"]
X = student_data[["Age", "Tardies"]]
lm = LinearRegression()
model = lm.fit(X, Y)


print("Intercept: ", lm.intercept_)
print("Coef: ", lm.coef_)

predictions  = lm.predict(X)   ## Y predicted
# Out:
# Intercept:  2.6645352591003757e-15
# Coef:  [-4.32243275e-17  1.00000000e+00]

# %% [markdown]
# Plot your regression model on your scatter plot.

# %%
sns.regplot(x='Tardies', y='Age', data=student_data)

# %% [markdown]
# Interpret the results of your model. What can conclusions can you draw from your model and how confident in these conclusions are you? Can we say that age is a good predictor of tardiness? Add your responses as comments after your code.

# %%
# Your response here.  
'''Yes! I'm quite confident but to confirm we need a bigger dataset. In the regessionplot we see the
error is not to big and the interval is also has the same trend.'''

# %% [markdown]
# ## Challenge 2
# For the second part of this lab, we will use the vehicles.csv data set. You can find a copy of the dataset in the git hub folder. This dataset includes variables related to vehicle characteristics, including the model, make, and energy efficiency standards, as well as each car's CO2 emissions. As discussed in class the goal of this exercise is to predict vehicles' CO2 emissions based on several independent variables.

# %%
# Import any libraries you may need & the data, already done in the first cell :) 
df = pd.read_csv('vehicles.csv')
df
# Out:
#                         Make                Model  Year  Engine Displacement  \
# 0                 AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1                 AM General     FJ8c Post Office  1984                  4.2
# 2                 AM General  Post Office DJ5 2WD  1985                  2.5
# 3                 AM General  Post Office DJ8 2WD  1985                  4.2
# 4           ASC Incorporated                  GNX  1987                  3.8
# 5                      Acura          2.2CL/3.0CL  1997                  2.2
# 6                      Acura          2.2CL/3.0CL  1997                  2.2
# 7                      Acura          2.2CL/3.0CL  1997                  3.0
# 8                      Acura          2.3CL/3.0CL  1998                  2.3
# 9                      Acura          2.3CL/3.0CL  1998                  2.3
# 10                     Acura          2.3CL/3.0CL  1998                  3.0
# ...

# %% [markdown]
# Let's use the following variables for our analysis: Year, Cylinders, Fuel Barrels/Year, Combined MPG, and Fuel Cost/Year. We will use 'CO2 Emission Grams/Mile' as our outcome variable.
#
# Calculate the correlations between each of these variables and the outcome. Which variable do you think will be the most important in determining CO2 emissions? Which provides the least amount of helpful information for determining CO2 emissions? Add your responses as comments after your code.

# %%
# Your response here. 
cor_C_Y = df[["Year", "CO2 Emission Grams/Mile"]].corr()
cor_C_Cy = df[["CO2 Emission Grams/Mile", "Cylinders"]].corr()
cor_C_F = df[["CO2 Emission Grams/Mile", "Fuel Barrels/Year"]].corr()
cor_C_CMPG = df[["CO2 Emission Grams/Mile", "Combined MPG"]].corr()
cor_C_CY = df[["CO2 Emission Grams/Mile", "Fuel Cost/Year"]].corr()

cor_C_Y
# Out:
#                            Year  CO2 Emission Grams/Mile
# Year                     1.0000                  -0.2223
# CO2 Emission Grams/Mile -0.2223                   1.0000

# %%
cor_C_Cy
# Out:
#                          CO2 Emission Grams/Mile  Cylinders
# CO2 Emission Grams/Mile                 1.000000   0.752393
# Cylinders                               0.752393   1.000000

# %%
cor_C_F
# Out:
#                          CO2 Emission Grams/Mile  Fuel Barrels/Year
# CO2 Emission Grams/Mile                 1.000000           0.986189
# Fuel Barrels/Year                       0.986189           1.000000

# %%
cor_C_CMPG
# Out:
#                          CO2 Emission Grams/Mile  Combined MPG
# CO2 Emission Grams/Mile                 1.000000     -0.926229
# Combined MPG                           -0.926229      1.000000

# %%
cor_C_CY
# Out:
#                          CO2 Emission Grams/Mile  Fuel Cost/Year
# CO2 Emission Grams/Mile                 1.000000        0.930865
# Fuel Cost/Year                          0.930865        1.000000

# %%
'''CO2 Emission Grams/Mile & Fuel Barrels/Year and CO2 Emission Grams/Mile & Fuel Cost/Year, while the fell bars and miles
are also closely related and burning the Fuel aka driving the miles will give C02 emission. 

Year is a static value which if you don't get a 'real' 0 value is completly useless to calculate with

'''

# %% [markdown]
# Build a regression model for this data. What type of regression are you using? Add your responses as comments after your code.

# %%
# Your response here. 

Y = df["CO2 Emission Grams/Mile"]
X = df[["Fuel Barrels/Year", "CO2 Emission Grams/Mile"]]
lm = LinearRegression()
model = lm.fit(X, Y)


print("Intercept: ", lm.intercept_)
print("Coef: ", lm.coef_)

predictions  = lm.predict(X)   ## Y predicted


'''I've used the one with the highest correlation coefficient with the outcome of CO2 Emission Grams/Mile" as a result of the
input in the formula. '''
# Out:
# Intercept:  1.9895196601282805e-12
# Coef:  [-2.5291628e-13  1.0000000e+00]

# %% [markdown]
# Print your regression summary, and interpret the results. What are the most important varibles in your model and why? What can conclusions can you draw from your model and how confident in these conclusions are you? Add your responses as comments after your code.

# %%
sns.regplot(y='CO2 Emission Grams/Mile', x='Fuel Barrels/Year', data=df)

'''I'm quite confident in my conclusions, but I would do a research too all the outliers at the left-hand side
(why is there a line of vertical values that are outliers? How does that influences getting them out/changing them my line?)
Maybe it's the CO2 emissions from producing the cars?'''

# %% [markdown]
# ## Challenge 3: Error Analysis

# %% [markdown]
# I am suspicious about the last few parties I have thrown: it seems that the more people I invite the more people are unable to attend. To know if my hunch is supported by data, I have decided to do an analysis. I have collected my data in the table below, where X is the number of people I invited, and Y is the number of people who attended.
#
# |  X |  Y |
# |----|----|
# | 1  |  1 |
# | 3  |  2 |
# | 4  |  4 |
# | 6  |  4 |
# | 8  |  5 |
# | 9  |  7 |
# | 11 |  8 |
# | 14 |  13 |

# %% [markdown]
# We want to know if the relationship modeled by the two random variables is linear or not, and therefore if it is appropriate to model it with a linear regression.
# First, build a dataframe with the data.

# %%
partytime = pd.DataFrame({'Invited People': [1, 3, 4, 6, 8, 9, 11, 14], 'Real Friends': [1, 2, 4, 4, 5, 7, 8, 13]})
partytime
# Out:
#    Invited People  Real Friends
# 0               1             1
# 1               3             2
# 2               4             4
# 3               6             4
# 4               8             5
# 5               9             7
# 6              11             8
# 7              14            13

# %% [markdown]
# Draw a dispersion diagram (scatter plot) for the data, and fit a regression line.

# %%
plt.scatter(x="Invited People", y="Real Friends", data=partytime)
plt.xlabel('Invited People') 
plt.ylabel('Real Friends') 

x = np.linspace(0,16,100)
y = 0.85*x+-0.44

plt.plot(x, y, '-r', label='y=2x+1')

# %%
X = partytime["Invited People"]
Y = partytime["Real Friends"]

slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)  
print ('The slope is: ' + str(slope))
print ('The intercept is: ' + str(intercept))
print ('the r-value is:'+ str(r_value))

'''y=ax+b
y=0.85x+-0.44'''
# Out:
# The slope is: 0.8484848484848485
# The intercept is: -0.43939393939393945
# the r-value is:0.9652303546573691
# 'y=ax+b\ny=0.85x+-0.44'

# %% [markdown]
# What do you see? What does this plot tell you about the likely relationship between the variables? Print the results from your regression.

# %%
# Your response here. 
'''the likely hood of the seems to be quite big as the r-value is 0.97.'''

# %% [markdown]
# Do you see any problematic points, or outliers, in your data? Remove these points and recalculate your regression. Print the new dispersion diagram with your new model and the results of your model.

# %%
# Your response here. 
''''The only problem I see is that there are not enough parties trown and 
enough people invited. If I would have to get point out it would be and index 4 &
6 or index 0 & 2 while they have a 100% score and are smale samples which means they are not repreentative.'''

# %%
partytime1 = partytime.drop([0, 2])
X = partytime1["Invited People"]
Y = partytime1["Real Friends"]

plt.scatter(x="Invited People", y="Real Friends", data=partytime1)
plt.xlabel('Invited People') 
plt.ylabel('Real Friends') 

x = np.linspace(0,16,100)
y = 0.97*x+-1.77

plt.plot(x, y, '-r', label='y=2x+1')


slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)  
print ('The slope is: ' + str(slope))
print ('The intercept is: ' + str(intercept))
print ('the r-value is:'+ str(r_value))
# Out:
# The slope is: 0.9727891156462585
# The intercept is: -1.7687074829931966
# the r-value is:0.9727891156462585

# %%
partytime2 = partytime.drop([4, 6])
X = partytime2["Invited People"]
Y = partytime2["Real Friends"]

plt.scatter(x="Invited People", y="Real Friends", data=partytime2)
plt.xlabel('Invited People') 
plt.ylabel('Real Friends') 

x = np.linspace(0,16,100)
y = 0.91*x+-0.44

plt.plot(x, y, '-r', label='y=2x+1')


slope, intercept, r_value, p_value, std_err = stats.linregress(X, Y)  
print ('The slope is: ' + str(slope))
print ('The intercept is: ' + str(intercept))
print ('the r-value is:'+ str(r_value))
# Out:
# The slope is: 0.9097744360902255
# The intercept is: -0.44360902255639
# the r-value is:0.9835318283381996

# %% [markdown]
# What changed? Based on the results of the two models and your graphs, what can you say about the form of the data with the problematic point and without it?

# %%
# Your response here. 
'''it doesn't really make a big difference, but dropping index 4 and 6 gives the best result.'''
